# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # Importing the image module
from PIL import Image # Importing the Image class from PIL

# %%
img= mpimg.imread('star.jpg')
# img
# print(img.shape) # Displaying the shape of the image
print(img) # Displaying the image array
# Out:
# [[[206 206 206]
#   [206 206 206]
#   [206 206 206]
#   ...
#   [206 206 206]
#   [206 206 206]
#   [206 206 206]]
#
#  [[206 206 206]
#   [206 206 206]
#   [206 206 206]
#   ...
#   [206 206 206]
#   [206 206 206]
#   [206 206 206]]
#
#  [[206 206 206]
#   [206 206 206]
#   [206 206 206]
#   ...
#   [206 206 206]
#   [206 206 206]
#   [206 206 206]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
plt.imshow(img)

# %%
# Pseudo Images

lum_img = img[:,:,0] # Extracting the luminance channel
# plt.imshow(lum_img)

# plt.imshow(lum_img, cmap='gray') # Displaying in grayscale
plt.imshow(lum_img, cmap='hot') # Displaying in hot colormap

# %%
lum_img = img[:,:,0] # Extracting the luminance channel
plt.imshow(lum_img)
plt.colorbar()

# %%
plt.imshow(lum_img, cmap='hot')
plt.colorbar()

# %%
img = Image.open('star.jpg')

# %%
# Use LANCZOS resampling (equivalent to old ANTIALIAS)
img.thumbnail((64, 64), Image.Resampling.LANCZOS)

plt.imshow(img)

# %%
# Use LANCZOS resampling (equivalent to old ANTIALIAS)
img.thumbnail((64, 64), Image.Resampling.LANCZOS)

plt.imshow(img, interpolation='bicubic') # Using bicubic interpolation
