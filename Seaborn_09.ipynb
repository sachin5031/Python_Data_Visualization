# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=sb.load_dataset("tips") # Load the tips dataset from seaborn github repository

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill', y='tip', data=df, hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x="total_bill", y="tip", data=df, kind='line')
plt.show()

sns.relplot(x="total_bill", y="tip", data=df, kind='line', style='day', hue='day', markers=True, dashes=False)
plt.show()

sns.relplot(x="total_bill", y="tip", data=df, kind='line', style='day', hue='day', markers=True, dashes=True)
plt.show()

# %%
sns.relplot(x='day', y='tip', data=df, kind='scatter')
plt.show()

# %% [markdown]
# ### ci In Seaborn
# In seaborn, `ci` stands for "confidence interval". It is a parameter used in plotting functions (such as `sns.lineplot`, `sns.barplot`, etc.) to indicate the size of the confidence interval to draw around estimated values. By default, seaborn shows a 95% confidence interval (`ci=95`). You can set `ci=None` to hide the confidence interval, or specify another value (e.g., `ci=68` for a 68% interval).
#
# **Example usage:**
# ```python
# sns.lineplot(x='total_bill', y='tip', data=df, ci=95)
# ```
#
# **Common values for `ci`:**
# - `ci=95`: 95% confidence interval (default)
# - `ci=None`: No confidence interval
# - `ci="sd"`: Show standard deviation instead of confidence interval
# - `ci=68`: 68% confidence interval
#
# The confidence interval provides a visual indication of the uncertainty around the estimated values.

# %%
sns.relplot(x='day', y='tip', data=df, kind='line')
plt.show()

# %%
sns.relplot(x='day', y='tip', data=df, kind='line', ci='sd')
sns.relplot(x='day', y='tip', data=df, kind='line', ci=None)
sns.relplot(x='day', y='tip', data=df, kind='line', ci=68)
plt.show()
# Out:
# c:\Users\sachi\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\sachi\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# c:\Users\sachi\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %%
sns.catplot(x='day', data=df, kind='count')
sns.catplot(x='day', data=df, kind='bar')
sns.catplot(x='day', data=df, kind='box')
sns.catplot(x='day', data=df, kind='violin')

# %%
sns.catplot(x='smoker', data=df, kind='count')
sns.catplot(x='smoker', data=df, kind='bar')
sns.catplot(x='smoker', data=df, kind='box')

# %%
category_order=['No', 'Yes']
sns.catplot(x='smoker', data=df, kind='count', order=category_order)
