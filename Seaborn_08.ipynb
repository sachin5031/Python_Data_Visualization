# %% [markdown]
# # Seaborn
#     Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics. Seaborn makes it easy to visualize data distributions, relationships, and categorical data, and it integrates well with pandas DataFrames for quick plotting and analysis.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sb

# %%
height = [105, 110, 115, 120, 125, 130, 135, 140, 145, 150]
weight = [20, 22, 24, 26, 28, 30, 32, 34, 36, 38]   

sns.scatterplot(x=height, y=weight)
# Out:
# <Axes: >

# %%
gender= ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female', 'Male','Male', 'Male']


sns.countplot(x=gender, hue=gender)
plt.show()

# %%
df=sb.load_dataset("tips") # Load the tips dataset from seaborn github repository

df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.to_csv('tips.csv', index=False)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.scatterplot(x='total_bill', y='tip', data=df)
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', data=df,hue='smoker')
plt.show()

# %%
sns.scatterplot(x='total_bill', y='tip', data=df, hue='smoker', hue_order=['No', 'Yes'])
plt.show()

# %%
hue_color = {'Yes': 'black', 'No': 'red'}
sns.scatterplot(x='total_bill', y='tip', data=df, hue='smoker', hue_order=['Yes', 'No'], palette=hue_color)
plt.show()

# %%
sns.countplot(x='sex', data=df, hue='smoker')
plt.show()

# %%
sns.countplot(x='smoker', data=df, hue='sex')
plt.show()

# %% [markdown]
# ### relplot in Seaborn
#
# `relplot` is a figure-level function in Seaborn used for visualizing relationships between variables. It can create scatter plots (`kind='scatter'`) and line plots (`kind='line'`). `relplot` combines the flexibility of FacetGrid with the convenience of high-level plotting, allowing for easy creation of multi-plot grids based on categorical variables.
#
# **Example:**
# ```python
# sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', hue='smoker')
# ```

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', hue='smoker')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='line', hue='smoker')
plt.show()

# %% [markdown]
# ### Subplot in Seaborn
# You can use the `row` and `col` parameters in `relplot` to create subplots based on categorical variables. For example, `row='sex'` and `col='day'` will create a grid of scatter plots, with rows for each sex and columns for each day. This helps visualize how relationships differ across categories.

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', row='smoker')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', col='smoker')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='line', col='smoker')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='line', col='sex')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='line', col='day')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='line', col='time')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', col='smoker', row='time')

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', col='smoker', row='day', hue='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', col='smoker', row='time', hue='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', col='day', col_wrap=2, col_order=['Thur', 'Fri', 'Sat', 'Sun'])

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', hue='smoker', col='day', col_wrap=2, col_order=['Thur', 'Fri', 'Sat', 'Sun'])

# %% [markdown]
# ### Using `size`, `hue`, and `alpha` in Seaborn
#
# - **`size`**: Maps a variable to the marker size in scatter plots, allowing you to visualize a third numeric variable by varying the point sizes.
# - **`hue`**: Maps a variable to color, distinguishing categories or values visually.
# - **`alpha`**: Controls the transparency of the markers (0 is fully transparent, 1 is fully opaque), useful for reducing overplotting.
#
# **Example:**
# ```python
# sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', size='size', hue='size', alpha=0.5)
# plt.show()
# ```
# This example visualizes the relationship between `total_bill` and `tip`, with marker size and color representing the `size` variable, and transparency set to 0.5.

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', size='size', hue='size')
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', data=df, kind='scatter', size='size', hue='size', alpha=0.5)
plt.show()
